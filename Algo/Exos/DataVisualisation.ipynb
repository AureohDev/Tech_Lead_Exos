# %% [markdown]
# <a href="https://colab.research.google.com/github/AureohDev/Tech_Lead_Exos/blob/main/Algo/Exos/DataVisualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualisation Statistiques descriptives
#
# ## I. Visualisation d’un nuage de points et exploration des variables
#
# Pour cette partie, nous allons utiliser le dataset suivante : ***house_pricing.csv*** que vous pouvez trouver dans le dossier ***Data Sources***. Nous allons tenter de comprendre un peu mieux ce dataset
# par la visualisation
#
# 1. Importez les librairies qu'il faut (pandas, seaborn, matplotlib, numpy)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline   

from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks/Sources/'
data_hp = pd.read_csv(root_path+'house_pricing.csv', sep = ',')

data_hp.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# 2. Donnez la liste des variables présentes dans ce dataset ainsi que leur nature (sont elles qualitatives, quantitatives, discrète, etc...) et leur type (float, int, str, etc...)

# %%
data_hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# 3. En créant. un nuage de points, regardez comment se comporte la colonne ***LotArea*** par rapport au ***SalesPrices***

# %%
sns.relplot(x="LotArea", y="SalePrice", data = data_hp, height=6);

# %% [markdown]
# 4. Affinez votre visualisaition en ne gardant uniquement les maisons qui on un ***LotArea*** inférieur a 20 000 pieds carrés et prix inférieur à 500 000$

# %%
sns.relplot(x="LotArea", y="SalePrice", data = data_hp.query("LotArea < 20000 & SalePrice < 500000"), height=6);

# %% [markdown]
# 5. En créant un nuage de points, regardez la relation entre le ***LotFrontage*** et le ***LotArea***

# %%
sns.relplot(x="LotArea", y="LotFrontage", data = data_hp, height=6);

# %% [markdown]
# 6. De la même manière, affinez votre visualisation en ne gardant uniquement les maisons qui ont un ***LotFrontage*** inférieur à 200 pieds carrés et un ***LotArea*** inférieur à 100 000 pieds carré.

# %%
sns.relplot(x="LotArea", y="LotFrontage", data = data_hp.query("LotFrontage < 200 & LotArea < 100000"), height=6);

# %% [markdown]
# ## II. Visualisation de relations continues
#
# Pour cette partie, nous utiliserons le dataset suivant : ***sales_predictions.csv*** que vous pouvez trouver dans le dossier des ***Data Source***.
#
# 1. Importez les libraries qu'il vous faut

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline   

from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks/Sources/'
data_sp = pd.read_csv(root_path+'sales_predictions.csv', sep = ',')

data_sp.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
data_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %% [markdown]
# 2. En utilisant ***relplot()***, construisez un graphique qui va vous permettre de voir l’évolution des
# prix par rapport au temps. Que pouvez-vous voir ?

# %%
sns.relplot(x = 'date', y = 'item_price', data=data_sp)

# %% [markdown]
# 3. Corrigeons le problème de visualisation, en utilisant la fonction ***.sample()*** de Pandas, prenez
# un échantillons de 50 éléments dans votre dataset

# %%
sns.relplot(x = 'date', y = 'item_price', data=data_sp.sample(50))

# %% [markdown]
# 4. Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez-vous ?

# %%
sns.relplot(x = "date", y = "item_price", data = data_sp.sample(50), height= 6, aspect = 3, kind="line")

# %% [markdown]
# 5. En utilisant la fonction ***pd.to_datetime()***, convertissez votre colonne date en ***datetime***

# %%
data_sp['date'] = pd.to_datetime(data_sp['date'])
data_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            datetime64[ns]
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 134.4 MB

# %% [markdown]
# 6. Retentez une dernière fois votre virtualisation.

# %%
sns.relplot(x = "date", y = "item_price", data = data_sp.sample(50), height= 6, aspect = 3, kind='line')

# %% [markdown]
# ## III. Visualisation des variables catégoriques
#
# Pour cette partie, nous utiliserons le dataset suivant : ***ibm_hr_attrition.csv*** que vous pouvez trouver dans le dossier **Data Sources**
#
# 1. Importez les librairies qu'il vous faut

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline   

from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks/Sources/'
data_ibm = pd.read_csv(root_path+'IBM_HR_ATTRITION.csv', sep = ',')

data_ibm.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# 2. En utilisant ***catplot()***, construisez un graphique qui vous permette de voir la distribution des personnes qui ont quitté l'entreprise par rapport à leur ***JobSatisfaction***

# %%
sns.catplot(x="JobSatisfaction", y="Attrition", data=data_ibm)

# %% [markdown]
# 3. Changez de graphique et utilisez plutôt un boxplot, que pouvez vous conclure ?

# %%
sns.boxplot(x="JobSatisfaction", y="Attrition", data=data_ibm)

# On peut affirmer que ceux insatisfait de leur job ont quitté l'entreprise 
# Tandis que ce satisfait sont restés dans l'entreprise

# %% [markdown]
# 4. Peut-on dire grâce aux boxplot si une variable présente des valeurs aberrantes

# %%
# Il n'y a aucune valeurs aberrantes, s'il y en avait on aurait pu faire le filtre suivant :

#Si on a un JobSatisfaction < 0 ou JobSatisfaction > 4

# %% [markdown]
# 5. Isolez les observations présentant des valeurs aberrante pour la variable JobSatifaction en fonction de la variable indiquant s'ils ont quitté l'entreprise ou non

# %%
data_ibm[(data_ibm['JobSatisfaction'] > 4) | (data_ibm['JobSatisfaction'] < 1)]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []

# %% [markdown]
# 6. Utilisez la méthode ***.describe*** de pandas pour obtenir un tableau récapitualtif des statistiques descriptives du dataset.

# %%
data_ibm.JobSatisfaction.describe(include="all")
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %% [markdown]
# 7. Comparez les individus présentant des valeurs aberrantes pour la variable ***JobSatisfaction*** avec les statistiques descriptives du dataset, remarquez vous une différences notoires ?

# %%
sns.catplot(x="JobSatisfaction", y="Attrition", data=data_ibm[data_ibm['JobSatisfaction']<20], kind="box", height=7)

# %% [markdown]
# 8. Faites de mêmeavec le ***TotalWorkingYears***. Que pouvez-vous conclure ?

# %%
sns.catplot(x="TotalWorkingYears", y="Attrition", data=data_ibm, kind="box", height=7)

# %%
sns.catplot(x="TotalWorkingYears", y="Attrition", data=data_ibm[data_ibm['TotalWorkingYears']<20], kind="box", height=7)

# %% [markdown]
# 9. Remplacer les valeurs de la colonne Attrition par 1 pour ***Yes*** et 0 pour ***No***

# %%
data_ibm.Attrition =  data_ibm.Attrition.replace(to_replace=["Yes","No"], value=[0,1])
data_ibm.head()
# Out:
#    Age  Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41          0  ...                       0                     5
# 1   49          1  ...                       1                     7
# 2   37          0  ...                       0                     0
# 3   33          1  ...                       3                     0
# 4   27          1  ...                       2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# 10. En utilisant un Histogramme, regardez la répartition du taux de départ de ***EducationField***

# %%
sns.catplot(x="EducationField",y="Attrition",data=data_ibm,kind="bar",height=9)

# %% [markdown]
# ## IV. Visualisation d'une distribution
#
# Continuons sur ***ibm_hr_attrition.csv***
#
# 1. Importez les librairies qu'il vous faut

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline   

from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks/Sources/'
data_ibm = pd.read_csv(root_path+'IBM_HR_ATTRITION.csv', sep = ',')

data_ibm.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# 2. En utilisant ***displot()***, construisez un graphique qui permet de voir la distribution des revenues par mois chez ***IBM(MonthlyIncome)***

# %%
sns.displot(x=data_ibm.MonthlyIncome)

# %% [markdown]
# 3. On peut voir que les très haut salaires biaisent notre distribution, essayons de voir la distribution des salaires entre 0 et 5000$ / mois

# %%
sns.displot(data=data_ibm[(data_ibm['MonthlyIncome'] > 0) & (data_ibm['MonthlyIncome'] < 5000)], x="MonthlyIncome")

# %% [markdown]
# ## V. Visualisation d'une relation linéaire
#
# Toujours sur ***ibm_hr_attrition.csv***
#
# 1. Importez les librairies qu'il vous faut

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline   

from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks/Sources/'
data_ibm = pd.read_csv(root_path+'IBM_HR_ATTRITION.csv', sep = ',')

data_ibm.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# 2. On voudrait connaître la probabilité de partir de l'entreprise par rapport à la distance par rapport à la maison. Utilisez ***Implot()*** pour visualiser cela. Que pouvez-vous conclure ?

# %%
data_ibm.Attrition = data_ibm.Attrition.replace(to_replace = ["Yes","No"], value=[1,0])
sns.lmplot(x="DistanceFromHome",y="Attrition", data = data_ibm)

#On peut conclure que la distance Maison - Travail influe sur les départs de l'entreprise

# %% [markdown]
# 3. Tentez le cette fois avec le nombre d'années passées avec le Manager (***YearsWithCurrManager***), que pouvez-vous conlure ?

# %%
sns.lmplot(x="YearsWithCurrManager", y="Attrition", data=data_ibm)

# %% [markdown]
# ## VI. Visualisation d'une heatmap
#
# Revenons sur ***house_princing.csv***, et tentons de faire un peu de ce qu'on appelle communément : ***feature_engineering***
#
# 1. Importez les libraires habituelles

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline   

from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks/Sources/'
data_hp = pd.read_csv(root_path+'house_pricing.csv', sep = ',')

data_hp.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# 2. Découpez votre dataset pour ne garder que les 15 dernières colonnes

# %%
data_hp[-15:]
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 1445  1446          85       RL  ...        WD         Normal    129000
# 1446  1447          20       RL  ...        WD         Normal    157900
# 1447  1448          60       RL  ...        WD         Normal    240000
# 1448  1449          50       RL  ...        WD         Normal    112000
# 1449  1450         180       RM  ...        WD        Abnorml     92000
# 1450  1451          90       RL  ...        WD         Normal    136000
# 1451  1452          20       RL  ...       New        Partial    287090
# 1452  1453         180       RM  ...        WD         Normal    145000
# 1453  1454          20       RL  ...        WD        Abnorml     84500
# 1454  1455          20       FV  ...        WD         Normal    185000
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# ...

# %% [markdown]
# 3. Créez une matrice de corrélation avec toutes les varibales du Dataset

# %%
data_hp.iloc[:, -15:].corr()
# Out:
#                WoodDeckSF  OpenPorchSF  ...    YrSold  SalePrice
# WoodDeckSF       1.000000     0.058661  ...  0.022270   0.324413
# OpenPorchSF      0.058661     1.000000  ... -0.057619   0.315856
# EnclosedPorch   -0.125989    -0.093079  ... -0.009916  -0.128578
# 3SsnPorch       -0.032771    -0.005842  ...  0.018645   0.044584
# ScreenPorch     -0.074181     0.074304  ...  0.010694   0.111447
# PoolArea         0.073378     0.060762  ... -0.059689   0.092404
# MiscVal         -0.009551    -0.018584  ...  0.004906  -0.021190
# MoSold           0.021011     0.071255  ... -0.145721   0.046432
# YrSold           0.022270    -0.057619  ...  1.000000  -0.028923
# SalePrice        0.324413     0.315856  ... -0.028923   1.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# 4. Créez une heatmap avec les différentes valeurs de corrélation

# %%
f, ax = plt.subplots(figsize=(20,5))
sns.heatmap(data = data_hp.iloc[:, -15:].corr(), annot=True, ax=ax)

# %% [markdown]
# 5. Quel est le top 3 des features qu'on devrait garder  pour prédire notre prix ?

# %%
print('WoodDeckSF / OpenPorchSF / ScreenPorch')
# Out:
# WoodDeckSF / OpenPorchSF / ScreenPorch
